# %% [markdown]
# <a href="https://colab.research.google.com/github/angelicacarvalhodasilva26-wq/INTMI_2025/blob/main/Lista3_angel_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [int(input("Digite um número: ")) for _ in range(15)]
result = []
for n in nums:
    if n not in result:
        result.append(n)
print(result)

# %%
nomes = []
idades = []

for i in range(10):
    nomes.append(input("Nome: "))
    idades.append(int(input("Idade: ")))

mais_velho = idades.index(max(idades))
print("Pessoa mais velha:", nomes[mais_velho])

# %%
lista = [int(input()) for _ in range(10)]
for i in range(len(lista)):
    if lista[i] % 2 == 0:
        lista[i] /= 2
    else:
        lista[i] /= 3
print(lista)

# %%
frase = input("Frase: ").split()
vogais = "aeiouAEIOU"
resultado = [p for p in frase if p[0] in vogais]
print(resultado)

# %%
import math

nums = [int(input()) for _ in range(10)]

def primo(n):
    if n < 2: return False
    for i in range(2, int(math.sqrt(n))+1):
        if n % i == 0:
            return False
    return True

primos = [n for n in nums if primo(n)]
print(primos)

# %%
lista = [input() for _ in range(8)]
if lista == lista[::-1]:
    print("É palíndroma")
else:
    print("Não é palíndroma")

# %%
import random

a = [random.randint(1,100) for _ in range(10)]
b = [random.randint(1,100) for _ in range(10)]
inter = [x for x in a if x in b]

print(a)
print(b)
print(inter)

# %%
import random
sorteio = random.sample(range(1, 61), 6)
print(sorteio)

# %%
lista = [int(input()) for _ in range(10)]
nova = []
soma = 0

for n in lista:
    soma += n
    nova.append(soma)

print(nova)

# %%
nomes = ["Ana", "Gabriel", "Fernandinha", "João Victor"]
final = [n for n in nomes if len(n) <= 10]
print(final)

# %%
mat = [[int(input()) for _ in range(4)] for _ in range(4)]
soma = 0

for i in range(4):
    soma += mat[i][3 - i]

print("Soma:", soma)

# %%
import random

mat = [[random.randint(1,99) for _ in range(5)] for _ in range(5)]
medias = [sum(linha)/5 for linha in mat]

print(mat)
print(medias)

# %%
mat = [[int(input()) for _ in range(3)] for _ in range(3)]
identidade = True

for i in range(3):
    for j in range(3):
        if i == j and mat[i][j] != 1:
            identidade = False
        if i != j and mat[i][j] != 0:
            identidade = False

print("É identidade?" , identidade)

# %%
mat = [[int(input()) for _ in range(3)] for _ in range(3)]
simetrica = mat == [[mat[j][i] for j in range(3)] for i in range(3)]
print("Simétrica?", simetrica)

# %%
mat = [[i * j for j in range(3)] for i in range(5)]
print(mat)

# %%
mat = [[int(input()) for _ in range(4)] for _ in range(4)]
menores = [min([mat[i][j] for i in range(4)]) for j in range(4)]
print(menores)

# %%
mat = [[float(input()) for _ in range(3)] for _ in range(3)]

det = (mat[0][0]*(mat[1][1]*mat[2][2] - mat[1][2]*mat[2][1])
     - mat[0][1]*(mat[1][0]*mat[2][2] - mat[1][2]*mat[2][0])
     + mat[0][2]*(mat[1][0]*mat[2][1] - mat[1][1]*mat[2][0]))

print("Determinante:", det)

# %%
A = {int(input()) for _ in range(10)}
B = {int(input()) for _ in range(10)}

print("Interseção:", A & B)
print("União:", A | B)
print("A - B:", A - B)
print("B - A:", B - A)

# %%
frase = input()
letras = {c.lower() for c in frase if c.isalpha()}
print(letras)

# %%
conj = {x for x in range(1,101) if x % 2 != 0 and x % 3 != 0}
print(conj)

# %%
resultado = {input("Palavra: ") for _ in range(10)}
resultado = {p for p in resultado if len(p) > 5}
print(resultado)

# %%
A = {int(input()) for _ in range(5)}
B = {int(input()) for _ in range(5)}

print("A ⊆ B ?" , A.issubset(B))
print("B ⊆ A ?" , B.issubset(A))

# %%
import math

conj = {int(input()) for _ in range(10)}
resultado = {x for x in conj if int(math.sqrt(x))**2 == x}
print(resultado)

# %%
func = {}

for _ in range(5):
    nome = input("Nome: ")
    sal = float(input("Salário: "))
    if sal < 2000:
        sal *= 1.10
    func[nome] = sal

print(func)

# %%
alunos = {}

for _ in range(5):
    nome = input("Nome: ")
    notas = [float(input()) for _ in range(3)]
    alunos[nome] = sum(notas) / 3

print(alunos)

# %%
sin = {
    "feliz": ["contente", "alegre"],
    "triste": ["abatido", "melancólico"]
}

palavra = input("Digite uma palavra: ")
print(sin.get(palavra, "Sem sinônimos cadastrados"))

# %%
dic = {}
for _ in range(10):
    palavra = input()
    letra = palavra[0].lower()
    dic.setdefault(letra, []).append(palavra)

print(dic)

# %%
prod = {
    "arroz": [20, 22, 19],
    "feijão": [8, 7.5, 9],
    "açúcar": [5, 5.5, 6]
}

maior_var = ""
valor_var = 0

for p, precos in prod.items():
    var = max(precos) - min(precos)
    if var > valor_var:
        valor_var = var
        maior_var = p

print("Maior variação:", maior_var)

# %%
frase = input().lower().split()
contagem = {}

for palavra in frase:
    contagem[palavra] = contagem.get(palavra, 0) + 1

print(contagem)
