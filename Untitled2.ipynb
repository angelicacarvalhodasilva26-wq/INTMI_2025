# %% [markdown]
# <a href="https://colab.research.google.com/github/angelicacarvalhodasilva26-wq/INTMI_2025/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

if idade >= 16:
    print("Você já pode votar.")

# %%
n1 = float(input("Nota 1: "))
n2 = float(input("Nota 2: "))
media = (n1 + n2) / 2

if media >= 7:
    print("Aprovado")
else:
    print("Reprovado")

# %%
temp = float(input("Temperatura: "))

if temp < 15:
    print("Fria")
elif temp < 25:
    print("Agradável")
elif temp < 35:
    print("Quente")
else:
    print("Muito quente")

# %%
num = int(input("Número: "))

if num % 2 == 0:
    print("Par")
else:
    print("Ímpar")

# %%
sal = float(input("Salário: "))

if sal <= 1500:
    novo = sal * 1.10
elif sal <= 3000:
    novo = sal * 1.07
else:
    novo = sal * 1.05

print("Novo salário:", novo)

# %%
a = float(input("A: "))
b = float(input("B: "))
c = float(input("C: "))

maior = a
if b > maior:
    maior = b
if c > maior:
    maior = c

print("Maior:", maior)

# %%
ano = int(input("Ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print("Ano bissexto")
else:
    print("Não é bissexto")

# %%
idade = int(input("Idade: "))

if idade < 12:
    print("Ingresso infantil")
else:
    print("Ingresso adulto")

# %%
cod = int(input("Código: "))

if cod == 1:
    print("Arroz")
elif cod == 2:
    print("Feijão")
elif cod == 3:
    print("Macarrão")
else:
    print("Código inválido")

# %%
hora = int(input("Hora (0-23): "))

if 5 <= hora < 12:
    print("Bom dia")
elif 12 <= hora < 18:
    print("Boa tarde")
elif 18 <= hora < 24:
    print("Boa noite")
else:
    print("Horário inválido")

# %%
soma = 0

while True:
    n = float(input("Número (0 para parar): "))
    if n == 0:
        break
    soma += n

print("Soma total:", soma)

# %%
senha = ""

while senha != "python123":
    senha = input("Digite a senha: ")

print("Bem-vindo!")

# %%
soma = 0
n = 1

while soma <= 100:
    print(n)
    soma += n
    n += 1

# %%
total = 0
cont = 0

while True:
    idade = int(input("Idade (negativa para parar): "))
    if idade < 0:
        break
    total += idade
    cont += 1

print("Média:", total / cont)

# %%
n = int(input("Número inicial: "))

while n >= 0:
    print(n)
    n -= 1

# %%
for i in range(1, 51):
    print(i)

# %%
num = int(input("Número: "))

for i in range(1, 11):
    print(f"{num} x {i} = {num*i}")

# %%
palavra = input("Palavra: ")

for letra in palavra:
    print(letra)

# %%
maiores = 0

for i in range(5):
    idade = int(input("Idade: "))
    if idade > 18:
        maiores += 1

print("Maiores de 18:", maiores)

# %%
maior = float('-inf')

for i in range(7):
    n = float(input("Número: "))
    if n > maior:
        maior = n

print("Maior número:", maior)

# %%
maior = ""

for i in range(4):
    tarefa = input("Nome da tarefa: ")
    if len(tarefa) > len(maior):
        maior = tarefa

print("Tarefa com maior nome:", maior)

# %%
soma = 0

for i in range(2, 101, 2):
    soma += i

print("Soma:", soma)

# %%
pos = neg = zero = 0

for i in range(10):
    n = float(input("Número: "))
    if n > 0:
        pos += 1
    elif n < 0:
        neg += 1
    else:
        zero += 1

print("Positivos:", pos)
print("Negativos:", neg)
print("Zeros:", zero)

# %%
for i in range(6):
    nome = input("Nome: ")
    if nome.upper().startswith(("A", "C")):
        print(nome)

# %%
while True:
    n = float(input("Número (999 para parar): "))
    if n == 999:
        break
    print("Você digitou:", n)

# %%
for i in range(1, 21):
    if i % 4 == 0:
        continue
    print(i)

# %%
for tentativa in range(3):
    senha = input("Senha: ")
    if senha == "python123":
        print("Acesso liberado")
        break
else:
    print("Acesso bloqueado")

# %%
soma = 0

for i in range(10):
    n = float(input("Número: "))
    if n < 0:
        continue
    soma += n

print("Soma dos positivos:", soma)

# %%
soma = 0
n = 1

while True:
    soma += n
    if soma > 200:
        break
    n += 1

print("Soma final:", soma)

# %%
cont = 0

while True:
    palavra = input("Palavra: ")
    if palavra.lower() == "fim":
        break
    cont += 1

print("Total de palavras:", cont)
